# %%
import numpy as np 
import matplotlib.pyplot as pyplot 


data = np.loadtxt('data.txt')
x = data[:, 0]
y1 = data[:, 1]
y2 = data[:, 2]

xx = [1024, 2048, 3072, 4096, 5120, 6144, 7168, 8192, 9216, 10240 ]
# print(np.max(y1/y2))
print(y1/y2)

pyplot.plot(x, y1, label = "Kernel 9", color = "coral")
pyplot.plot(x, y2, label = "cuBLAS", color = "blue")
pyplot.plot(x, y1, 'o', color = "darkred")
pyplot.plot(x, y2, 'P', color = "navy")
pyplot.ylim(0, 5000)
pyplot.ylabel("GFLOPS")
pyplot.xlabel("Matrix Size M=N=K")
pyplot.xticks(xx)
pyplot.legend()
pyplot.savefig("flops.png", dpi = 200)
pyplot.show()
# Out:
# [0.78496944 0.93457944 0.92713887 0.94296952 0.94826745 0.93297847
#  0.99933525 0.9988759  1.02409905 1.01141749 0.97802432 0.97966174
#  0.96065013 0.96782442 0.96437713]
